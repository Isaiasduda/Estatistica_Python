# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaiasduda/Estatistica_Python/blob/main/Estat%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# producao diaria de 2 empregados hipoteticos
empregadaA =  [70, 71, 69, 70, 70]
empregadoB =  [60, 80, 70, 62, 83]

# %%
# media de produçao
print('Media da producao:',
      '\nEmpregado A :', np.mean(empregadaA),
      '\nEmpregado B :', np.mean(empregadoB))
# Out:
# Media da producao:
# Empregado A : 70.0
# Empregado B : 71.0

# %%
from matplotlib import pyplot as plt

plt.plot(empregadaA, color='g')
plt.plot(empregadoB, color='r')
plt.ylabel('Producao')
plt.xlabel('Tempo')
plt.legend(['Empregado A', 'Empregado B'], loc='best')

plt.xticks([])

plt.show()
